# %%
import requests
from bs4 import BeautifulSoup as bs
import lxml

# %%
html = requests.get('https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8')

# %%
html
# Out:
# <Response [200]>

# %%
html.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<title>나무위키:대문 - 나무위키</title>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta http-equiv="x-pjax-version" content="5e54c48f0deebd97966928ab79d81c7c">\n<meta name="generator" content="the seed">\n<meta name="application-name" content="나무위키">\n<meta name="mobile-web-app-capable" content="yes">\n<meta name="msapplication-tooltip" content="나무위키">\n<meta name="msapplication-starturl" content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8">\n<link rel="canonical" href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8">\n<link rel="search" type="application/opensearchdescription+xml" title="나무위키" href="/opensearch.xml">\n<meta name="theme-color" content="#008275"><meta name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width">\n<link rel="shortcut icon" href="/favicon.ico">\n<link rel="icon" sizes="128x128" href="/img/i
# ...

# %%
doc = bs(html.text, 'lxml')

# %%
doc
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>나무위키:대문 - 나무위키</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>
# <meta content="the seed" name="generator"/>
# <meta content="나무위키" name="application-name"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="나무위키" name="msapplication-tooltip"/>
# <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
# <link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
# <meta content="#008275" name="theme-color"/><meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
body = doc.find_all('link')

# %%
body
# Out:
# [<link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>,
#  <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>,
#  <link href="/favicon.ico" rel="shortcut icon"/>,
#  <link href="/img/icon.png" rel="icon" sizes="128x128"/>,
#  <link href="/img/apple_icon.png" rel="apple-touch-icon"/>,
#  <link href="//creativecommons.org/licenses/by-nc-sa/2.0/kr/" rel="copyright"/>,
#  <link href="/css/diffview.css?05e3f5dd" rel="stylesheet"/>,
#  <link href="/css/katex.min.css?7ee60c84" rel="stylesheet"/>,
#  <link href="/css/wiki.css?39d536e6" rel="stylesheet"/>,
#  <link href="/skins/senkawa/css/lib/jquery-ui.min.css?840cca94" rel="stylesheet"/>,
#  <link href="/skins/senkawa/css/lib/bootstrap.min.css?f040bd43" rel="stylesheet"/>,
#  <link href="/skins/senkawa/css/lib/ionicons.min.css?2d4234e8" rel="stylesheet"/>,
#  <link href="/skins/senkawa/css/lib/nprogress.css?9dc52b7d" rel="stylesheet"/>,
# ...

# %%
for part in body :
    print(part['href'])
# Out:
# https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8
# /opensearch.xml
# /favicon.ico
# /img/icon.png
# /img/apple_icon.png
# //creativecommons.org/licenses/by-nc-sa/2.0/kr/
# /css/diffview.css?05e3f5dd
# /css/katex.min.css?7ee60c84
# /css/wiki.css?39d536e6
# /skins/senkawa/css/lib/jquery-ui.min.css?840cca94
# /skins/senkawa/css/lib/bootstrap.min.css?f040bd43
# /skins/senkawa/css/lib/ionicons.min.css?2d4234e8
# /skins/senkawa/css/lib/nprogress.css?9dc52b7d
# /skins/senkawa/css/bootstrap-fix.css?b43106c0
# /skins/senkawa/css/layout.css?b466e7da
# /skins/senkawa/css/wiki.css?2c03de5d
# /skins/senkawa/css/discuss.css?7fd2aa53
# /skins/senkawa/css/dark.css?93b91f32

# %%
body[1].find_next()
# Out:
# <meta content="#008275" name="theme-color"/>

# %%
parent = body[1].find_parents()

# %%
parent
# Out:
# [<head>
#  <title>나무위키:대문 - 나무위키</title>
#  <meta charset="utf-8"/>
#  <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#  <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>
#  <meta content="the seed" name="generator"/>
#  <meta content="나무위키" name="application-name"/>
#  <meta content="yes" name="mobile-web-app-capable"/>
#  <meta content="나무위키" name="msapplication-tooltip"/>
#  <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
#  <link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>
#  <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
#  <meta content="#008275" name="theme-color"/><meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
#  <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
for i in range(len(parent)):
    print(parent[i])
# Out:
# <head>
# <title>나무위키:대문 - 나무위키</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>
# <meta content="the seed" name="generator"/>
# <meta content="나무위키" name="application-name"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="나무위키" name="msapplication-tooltip"/>
# <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
# <link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
# <meta content="#008275" name="theme-color"/><meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
for i in range(len(parent)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
parent[0]
# Out:
# <head>
# <title>나무위키:대문 - 나무위키</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>
# <meta content="the seed" name="generator"/>
# <meta content="나무위키" name="application-name"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="나무위키" name="msapplication-tooltip"/>
# <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
# <link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
# <meta content="#008275" name="theme-color"/><meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
parent[1]
# Out:
# <html>
# <head>
# <title>나무위키:대문 - 나무위키</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>
# <meta content="the seed" name="generator"/>
# <meta content="나무위키" name="application-name"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="나무위키" name="msapplication-tooltip"/>
# <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
# <link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
# <meta content="#008275" name="theme-color"/><meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
parent[2]
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>나무위키:대문 - 나무위키</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>
# <meta content="the seed" name="generator"/>
# <meta content="나무위키" name="application-name"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="나무위키" name="msapplication-tooltip"/>
# <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
# <link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
# <meta content="#008275" name="theme-color"/><meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
a = parent[0].find_next_sibling()

# %%
a
# Out:
# <body class="senkawa">
# <script src="/skins/senkawa/js/layout.js?c6655d5d" type="text/javascript"></script>
# <div class="navbar-wrapper">
# <nav class="navbar navbar-dark bg-inverse navbar-static-top">
# <a class="navbar-brand wiki-logo" href="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8"></a>
# <ul class="nav navbar-nav">
# <li class="nav-item">
# <a class="nav-link" href="/RecentChanges" title="최근 변경">
# <span class="icon ion-compass"></span>
# <span class="icon-title">최근 변경</span>
# </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/RecentDiscuss" title="최근 토론">
# <span class="icon ion-android-textsms"></span>
# <span class="icon-title">최근 토론</span>
# </a>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button" title="특수 기능">
# <span class="icon ion-ios-gear"></span>
# <span class="icon-title">특수 기능</span>
# <span class="caret"></span>
# ...

# %%
parent = body[0].find_parent()

# %%
parent
# Out:
# <head>
# <title>나무위키:대문 - 나무위키</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>
# <meta content="the seed" name="generator"/>
# <meta content="나무위키" name="application-name"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="나무위키" name="msapplication-tooltip"/>
# <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>
# <link href="https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" rel="canonical"/>
# <link href="/opensearch.xml" rel="search" title="나무위키" type="application/opensearchdescription+xml"/>
# <meta content="#008275" name="theme-color"/><meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
parent = parent.find_all('meta')

# %%
parent
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="ie=edge" http-equiv="x-ua-compatible"/>,
#  <meta content="5e54c48f0deebd97966928ab79d81c7c" http-equiv="x-pjax-version"/>,
#  <meta content="the seed" name="generator"/>,
#  <meta content="나무위키" name="application-name"/>,
#  <meta content="yes" name="mobile-web-app-capable"/>,
#  <meta content="나무위키" name="msapplication-tooltip"/>,
#  <meta content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8" name="msapplication-starturl"/>,
#  <meta content="#008275" name="theme-color"/>,
#  <meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>,
#  <meta content="noarchive" name="googlebot"/>]

# %%
parent.find_all('meta', {'content' : '나무위키'})
# Out:
# [<meta content="나무위키" name="application-name"/>,
#  <meta content="나무위키" name="msapplication-tooltip"/>]

# %%
parent.find_all('meta',content = '나무위키')
# Out:
# [<meta content="나무위키" name="application-name"/>,
#  <meta content="나무위키" name="msapplication-tooltip"/>]

# %%
""
# Out:
# ''

# %%
+mm'''
































































































































































































































































'''''
